# %%
import nltk
nltk.download('punkt_tab')
from nltk import word_tokenize # tokenization
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
corpus= '''NLTK is a leading platform for building Python programs to work with human language data.
          It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet,
          along with a suite of text processing libraries for classification, tokenization, stemming,
          tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries,
          and an active discussion forum.'''

# %%
print(word_tokenize(corpus))
# Out:
# ['NLTK', 'is', 'a', 'leading', 'platform', 'for', 'building', 'Python', 'programs', 'to', 'work', 'with', 'human', 'language', 'data', '.', 'It', 'provides', 'easy-to-use', 'interfaces', 'to', 'over', '50', 'corpora', 'and', 'lexical', 'resources', 'such', 'as', 'WordNet', ',', 'along', 'with', 'a', 'suite', 'of', 'text', 'processing', 'libraries', 'for', 'classification', ',', 'tokenization', ',', 'stemming', ',', 'tagging', ',', 'parsing', ',', 'and', 'semantic', 'reasoning', ',', 'wrappers', 'for', 'industrial-strength', 'NLP', 'libraries', ',', 'and', 'an', 'active', 'discussion', 'forum', '.']

# %%
nltk.sent_tokenize(corpus) #converts it into the senternce format
# Out:
# ['NLTK is a leading platform for building Python programs to work with human language data.',
#  'It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, \n          along with a suite of text processing libraries for classification, tokenization, stemming, \n          tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries, \n          and an active discussion forum.']

# %%
from nltk.stem import PorterStemmer

# %%
ps=PorterStemmer()
token=word_tokenize(corpus)

# %%
for word in token:
    print(word+"---->"+ps.stem(word))
# Out:
# NLTK---->nltk
# is---->is
# a---->a
# leading---->lead
# platform---->platform
# for---->for
# building---->build
# Python---->python
# programs---->program
# to---->to
# work---->work
# with---->with
# human---->human
# language---->languag
# data---->data
# .---->.
# It---->it
# provides---->provid
# easy-to-use---->easy-to-us
# interfaces---->interfac
# to---->to
# over---->over
# 50---->50
# corpora---->corpora
# and---->and
# lexical---->lexic
# resources---->resourc
# such---->such
# as---->as
# WordNet---->wordnet
# ,---->,
# along---->along
# with---->with
# a---->a
# suite---->suit
# of---->of
# text---->text
# processing---->process
# libraries---->librari
# for---->for
# classification---->classif
# ,---->,
# tokenization---->token
# ,---->,
# stemming---->stem
# ,---->,
# tagging---->tag
# ,---->,
# parsing---->pars
# ,---->,
# and---->and
# semantic---->semant
# reasoning---->reason
# ,---->,
# wrappers---->wrapper
# for---->for
# industrial-strength---->industrial-strength
# NLP---->nlp
# libraries---->librari
# ,---->,
# and---->and
# an---->an
# active---->activ
# discussion---->discuss
# forum---->forum
# .---->.

# %%
# Lemmatization
# It is more accuarate than stemming ..
# Convert words into their root form
# need to download wordnet

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
for word in token:
    print(word+"---->"+lemmatizer.lemmatize(word))
# Out:
# NLTK---->NLTK
# is---->is
# a---->a
# leading---->leading
# platform---->platform
# for---->for
# building---->building
# Python---->Python
# programs---->program
# to---->to
# work---->work
# with---->with
# human---->human
# language---->language
# data---->data
# .---->.
# It---->It
# provides---->provides
# easy-to-use---->easy-to-use
# interfaces---->interface
# to---->to
# over---->over
# 50---->50
# corpora---->corpus
# and---->and
# lexical---->lexical
# resources---->resource
# such---->such
# as---->a
# WordNet---->WordNet
# ,---->,
# along---->along
# with---->with
# a---->a
# suite---->suite
# of---->of
# text---->text
# processing---->processing
# libraries---->library
# for---->for
# classification---->classification
# ,---->,
# tokenization---->tokenization
# ,---->,
# stemming---->stemming
# ,---->,
# tagging---->tagging
# ,---->,
# parsing---->parsing
# ,---->,
# and---->and
# semantic---->semantic
# reasoning---->reasoning
# ,---->,
# wrappers---->wrapper
# for---->for
# industrial-strength---->industrial-strength
# NLP---->NLP
# libraries---->library
# ,---->,
# and---->and
# an---->an
# active---->active
# discussion---->discussion
# forum---->forum
# .---->.

# %%
lemmatized_words = [lemmatizer.lemmatize(word) for word in token]
print(lemmatized_words)
# Out:
# ['NLTK', 'is', 'a', 'leading', 'platform', 'for', 'building', 'Python', 'program', 'to', 'work', 'with', 'human', 'language', 'data', '.', 'It', 'provides', 'easy-to-use', 'interface', 'to', 'over', '50', 'corpus', 'and', 'lexical', 'resource', 'such', 'a', 'WordNet', ',', 'along', 'with', 'a', 'suite', 'of', 'text', 'processing', 'library', 'for', 'classification', ',', 'tokenization', ',', 'stemming', ',', 'tagging', ',', 'parsing', ',', 'and', 'semantic', 'reasoning', ',', 'wrapper', 'for', 'industrial-strength', 'NLP', 'library', ',', 'and', 'an', 'active', 'discussion', 'forum', '.']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopword=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
filtered_tokens = [];
for word in token:
    if word not in stopword:
        filtered_tokens.append(word)
print(filtered_tokens)
# Out:
# ['NLTK',
#  'leading',
#  'platform',
#  'building',
#  'Python',
#  'programs',
#  'work',
#  'human',
#  'language',
#  'data',
#  '.',
#  'It',
#  'provides',
#  'easy-to-use',
#  'interfaces',
#  '50',
#  'corpora',
#  'lexical',
#  'resources',
#  'WordNet',
#  ',',
#  'along',
#  'suite',
#  'text',
#  'processing',
#  'libraries',
#  'classification',
#  ',',
#  'tokenization',
#  ',',
#  'stemming',
#  ',',
#  'tagging',
#  ',',
#  'parsing',
#  ',',
#  'semantic',
#  'reasoning',
#  ',',
#  'wrappers',
#  'industrial-strength',
#  'NLP',
#  'libraries',
#  ',',
#  'active',
#  'discussion',
#  'forum',
#  '.']

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()

# %%
for word in filtered_tokens:
    print(word+"---->"+ps.stem(word))
# Out:
# NLTK---->nltk
# leading---->lead
# platform---->platform
# building---->build
# Python---->python
# programs---->program
# work---->work
# human---->human
# language---->languag
# data---->data
# .---->.
# It---->it
# provides---->provid
# easy-to-use---->easy-to-us
# interfaces---->interfac
# 50---->50
# corpora---->corpora
# lexical---->lexic
# resources---->resourc
# WordNet---->wordnet
# ,---->,
# along---->along
# suite---->suit
# text---->text
# processing---->process
# libraries---->librari
# classification---->classif
# ,---->,
# tokenization---->token
# ,---->,
# stemming---->stem
# ,---->,
# tagging---->tag
# ,---->,
# parsing---->pars
# ,---->,
# semantic---->semant
# reasoning---->reason
# ,---->,
# wrappers---->wrapper
# industrial-strength---->industrial-strength
# NLP---->nlp
# libraries---->librari
# ,---->,
# active---->activ
# discussion---->discuss
# forum---->forum
# .---->.

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
for word in filtered_tokens:
    print(word+"---->"+lemmatizer.lemmatize(word))
# Out:
# NLTK---->NLTK
# leading---->leading
# platform---->platform
# building---->building
# Python---->Python
# programs---->program
# work---->work
# human---->human
# language---->language
# data---->data
# .---->.
# It---->It
# provides---->provides
# easy-to-use---->easy-to-use
# interfaces---->interface
# 50---->50
# corpora---->corpus
# lexical---->lexical
# resources---->resource
# WordNet---->WordNet
# ,---->,
# along---->along
# suite---->suite
# text---->text
# processing---->processing
# libraries---->library
# classification---->classification
# ,---->,
# tokenization---->tokenization
# ,---->,
# stemming---->stemming
# ,---->,
# tagging---->tagging
# ,---->,
# parsing---->parsing
# ,---->,
# semantic---->semantic
# reasoning---->reasoning
# ,---->,
# wrappers---->wrapper
# industrial-strength---->industrial-strength
# NLP---->NLP
# libraries---->library
# ,---->,
# active---->active
# discussion---->discussion
# forum---->forum
# .---->.
