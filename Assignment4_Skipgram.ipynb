# %%
import nltk
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download("punkt_tab")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# ===============================
# 1. Preprocessing
# ===============================
def preprocess(text):

    tokens = word_tokenize(text.lower())

    lemmatizer = WordNetLemmatizer()

    tokens = [
        lemmatizer.lemmatize(w)
        for w in tokens
        if w.isalpha()
    ]

    return tokens

# %%
# ===============================
# 2. Vocabulary
# ===============================
def build_vocab(tokens):

    vocab = list(set(tokens))

    word2idx = {w: i for i, w in enumerate(vocab)}
    idx2word = {i: w for i, w in enumerate(vocab)}

    return vocab, word2idx, idx2word

# %%
# ===============================
# 3. One Hot Encoding
# ===============================
def one_hot(word, word2idx, size):

    vec = np.zeros(size)

    if word in word2idx:
        vec[word2idx[word]] = 1

    return vec

# %%
# ===============================
# 4. Create Skip-Gram Data
# ===============================
def create_data(tokens, window=2):

    X, Y = [], []

    for i, target in enumerate(tokens):

        for j in range(max(0, i - window), min(len(tokens), i + window + 1)):

            if i != j:
                X.append(target)
                Y.append(tokens[j])

    return X, Y

# %%
# ===============================
# 5. Softmax
# ===============================
def softmax(x):

    e = np.exp(x - np.max(x))
    return e / np.sum(e)

# %%
# ===============================
# 6. Forward Propagation
# ===============================
def forward(x, W1, W2):

    h = np.dot(x, W1)        # Embedding
    y = np.dot(h, W2)

    return h, softmax(y)

# %%
# ===============================
# 7. Backward Propagation
# ===============================
def backward(x, h, y, t, W2):

    error = y - t

    dW2 = np.outer(h, error)
    dW1 = np.outer(x, np.dot(W2, error))

    return dW1, dW2

# %%
# ===============================
# 8. Train Word2Vec
# ===============================
def train(X, Y, word2idx, size, embed=10, lr=0.01, epochs=500):

    W1 = np.random.rand(size, embed)
    W2 = np.random.rand(embed, size)

    for e in range(epochs):

        loss = 0

        for target, context in zip(X, Y):

            x = one_hot(target, word2idx, size)
            t = one_hot(context, word2idx, size)

            h, y = forward(x, W1, W2)

            loss += -np.sum(t * np.log(y + 1e-9))

            dW1, dW2 = backward(x, h, y, t, W2)

            W1 -= lr * dW1
            W2 -= lr * dW2

        if e % 100 == 0:
            print("Epoch:", e, "Loss:", round(loss, 3))

    return W1, W2

# %%
# ===============================
# 9. Word Embeddings
# ===============================
def get_embeddings(W1, vocab):

    return {word: W1[i] for i, word in enumerate(vocab)}


# ===============================
# 10. Similar Words
# ===============================
def cosine(a, b):

    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))


def similar_words(word, embeddings, top=3):

    scores = {}

    for w, vec in embeddings.items():
        if w != word:
            scores[w] = cosine(embeddings[word], vec)

    return sorted(scores, key=scores.get, reverse=True)[:top]

# %%
# ===============================
# 11. Main
# ===============================
def main():

    corpus = """Python is a popular programming language.
    		 Machine learning models are trained with data.
    		 Artificial intelligence is rapidly advancing.
    		 Deep learning uses neural networks.
    		 Data science involves statistics and coding.
    		 Algorithms are fundamental to computer science.
    		 Cloud computing offers scalable solutions."""

    tokens = preprocess(corpus)
    print("Tokens:", tokens)

    vocab, word2idx, idx2word = build_vocab(tokens)
    size = len(vocab)

    X, Y = create_data(tokens)

    W1, W2 = train(X, Y, word2idx, size)

    embeddings = get_embeddings(W1, vocab)

    print("\nEmbedding Example:")
    print("python →", embeddings["python"])

    print("\nSimilar to 'python':")
    print(similar_words("python", embeddings))


# ===============================
# Run
# ===============================
if __name__ == "__main__":
    main()
# Out:
# Tokens: ['python', 'is', 'a', 'popular', 'programming', 'language', 'machine', 'learning', 'model', 'are', 'trained', 'with', 'data', 'artificial', 'intelligence', 'is', 'rapidly', 'advancing', 'deep', 'learning', 'us', 'neural', 'network', 'data', 'science', 'involves', 'statistic', 'and', 'coding', 'algorithm', 'are', 'fundamental', 'to', 'computer', 'science', 'cloud', 'computing', 'offer', 'scalable', 'solution']
# Epoch: 0 Loss: 564.01
# Epoch: 100 Loss: 305.097
# Epoch: 200 Loss: 257.298
# Epoch: 300 Loss: 252.404
# Epoch: 400 Loss: 251.207
#
# Embedding Example:
# python → [ 0.67508016  1.66461054 -0.99380141  0.05276374  0.05762258  0.7439584
#   1.58122614  0.36984386 -0.57444206 -1.46909152]
#
# Similar to 'python':
# ['popular', 'a', 'intelligence']
